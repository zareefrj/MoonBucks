# %% [markdown]
# # Finding the center

# %%
import numpy as np
import math
from numpy import array
from geopy.distance import geodesic
import gmplot

def weiszfeld(points):

    max_error = 0.0000000001

    x=np.array([point[0] for point in  points])
    y=np.array([point[1] for point in  points])


    ext_condition = True

    start_x = np.average(x)
    start_y = np.average(y)

    while ext_condition:

        sod = (((x - start_x)**2) + ((y - start_y)**2))**0.5

        new_x = sum(x/sod) / sum(1/sod)
        new_y = sum(y/sod) / sum(1/sod)

        ext_condition = (abs(new_x - start_x) > max_error) or (abs(new_y - start_y) > max_error)

        start_y = new_y
        start_x = new_x

        center_point = [start_x, start_y]

#     print(start_x, start_y)
    return calc_geodesic_dist(center_point, points)

#Using brute force method, can be optimised.
def calc_geodesic_dist(center_point, points):
    min_dist_from_center = 999999999999999999999999999999
    for point in points:
        if geodesic(point,center_point) < min_dist_from_center:
            min_dist_from_center = geodesic(point,center_point)
            center = point
    return center


if __name__=="__main__":
    # weiszfeld([(2,1), (12,2), (3,9), (13,11)]
    coordinates = [(49.276774,-123.12523), (49.841375,-119.487573), (49.500151,-117.283269), (49.23206,-123.032935), (51.08277, -114.154081)]
    center = weiszfeld(coordinates)
    print(center)
# Out:
# (49.841375, -119.487573)

# %% [markdown]
# # Request the Distance Matrix from Google API

# %%
import requests
import json
import urllib.parse
        
API_KEY = ""

# Used to parse into URL format
def urlparser(coordinates):
    n = len(coordinates)
    txt1 = [0] * n 
    for i in range(len(coordinates)):
        txt1[i] = ','.join(list(map(str, coordinates[i])))

    txt = '|'.join(txt1)
    return urllib.parse.quote(txt)

origins = urlparser(coordinates)
url = ('https://maps.googleapis.com/maps/api/distancematrix/json'
        + '?origins={}'
        + '&destinations={}'
        + '&key={}').format(origins, origins, API_KEY)

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
# Out:
# 49.276774%2C-123.12523%7C49.841375%2C-119.487573%7C49.500151%2C-117.283269%7C49.23206%2C-123.032935%7C51.08277%2C-114.154081

# %%
#Write to json
with open('distance.json', 'w') as f:
    json.dump(response.json(), f)

# %%
def tsp(data):
    # build a graph
    G = build_graph(data)
#   print("Graph: ", G)

    # build a minimum spanning tree
    MSTree = minimum_spanning_tree(G)
    # print("MSTree: ", MSTree)

    # find odd vertexes
    odd_vertexes = find_odd_vertexes(MSTree)
    # print("Odd vertexes in MSTree: ", odd_vertexes)

    # add minimum weight matching edges to MST
    minimum_weight_matching(MSTree, G, odd_vertexes)
    # print("Minimum weight matching: ", MSTree)

    # find an eulerian tour
    eulerian_tour = find_eulerian_tour(MSTree, G)

    # print("Eulerian tour: ", eulerian_tour)

    current = eulerian_tour[0]
    path = [current]
    visited = [False] * len(eulerian_tour)
    visited[eulerian_tour[0]] = True
    length = 0

    for v in eulerian_tour:
        if not visited[v]:
            path.append(v)
            visited[v] = True

            length += G[current][v]
            current = v

    length +=G[current][eulerian_tour[0]]
    path.append(eulerian_tour[0])

    print("Result path: ", path)
    print("Result length of the path: {} meter".format(length))

    return length, path

def build_graph(data):#O(n^2)
    # from json
    with open('distance.json') as  f:
        dist = json.load(f)
    
    graph = {}
    for point1 in range(len(data)):
        for point2 in range(len(data)):
            if point1 != point2:
                if point1 not in graph:
                    graph[point1] = {}

                graph[point1][point2] = dist['rows'][point1]['elements'][point2]['distance']['value']

    return graph


class UnionFind:
    def __init__(self):
        self.weights = {}
        self.parents = {}

    def __getitem__(self, object):
        if object not in self.parents:
            self.parents[object] = object
            self.weights[object] = 1
            return object

        # find path of objects leading to the root
        path = [object]
        root = self.parents[object]
        while root != path[-1]:
            path.append(root)
            root = self.parents[root]

        # compress the path and return
        for ancestor in path:
            self.parents[ancestor] = root
        return root

    def __iter__(self):
        return iter(self.parents)

    def union(self, *objects):
        roots = [self[x] for x in objects]
        heaviest = max([(self.weights[r], r) for r in roots])[1]
        for r in roots:
            if r != heaviest:
                self.weights[heaviest] += self.weights[r]
                self.parents[r] = heaviest


def minimum_spanning_tree(G):
    tree = []
    subtrees = UnionFind()
    for W, u, v in sorted((G[u][v], u, v) for u in G for v in G[u]):
        if subtrees[u] != subtrees[v]:
            tree.append((u, v, W))
            subtrees.union(u, v)

    return tree


def find_odd_vertexes(MST):
    tmp_g = {}
    vertexes = []
    for edge in MST:
        if edge[0] not in tmp_g:
            tmp_g[edge[0]] = 0

        if edge[1] not in tmp_g:
            tmp_g[edge[1]] = 0

        tmp_g[edge[0]] += 1
        tmp_g[edge[1]] += 1

    for vertex in tmp_g:
        if tmp_g[vertex] % 2 == 1:
            vertexes.append(vertex)

    return vertexes


def minimum_weight_matching(MST, G, odd_vert):
    import random
    random.shuffle(odd_vert)

    while odd_vert:
        v = odd_vert.pop()
        length = float("inf")
        u = 1
        closest = 0
        for u in odd_vert:
            if v != u and G[v][u] < length:
                length = G[v][u]
                closest = u

        MST.append((v, closest, length))
        odd_vert.remove(closest)


def find_eulerian_tour(MatchedMSTree, G):
    # find neigbours
    neighbours = {}
    for edge in MatchedMSTree:
        if edge[0] not in neighbours:
            neighbours[edge[0]] = []

        if edge[1] not in neighbours:
            neighbours[edge[1]] = []

        neighbours[edge[0]].append(edge[1])
        neighbours[edge[1]].append(edge[0])

    # print("Neighbours: ", neighbours)

    # finds the hamiltonian circuit
    start_vertex = MatchedMSTree[0][0]
    EP = [neighbours[start_vertex][0]]

    while len(MatchedMSTree) > 0:
        for i, v in enumerate(EP):
            if len(neighbours[v]) > 0:
                break

        while len(neighbours[v]) > 0:
            w = neighbours[v][0]

            remove_edge_from_matchedMST(MatchedMSTree, v, w)

            del neighbours[v][(neighbours[v].index(w))]
            del neighbours[w][(neighbours[w].index(v))]

            i += 1
            EP.insert(i, w)

            v = w

    return EP


def remove_edge_from_matchedMST(MatchedMST, v1, v2):

    for i, item in enumerate(MatchedMST):
        if (item[0] == v2 and item[1] == v1) or (item[0] == v1 and item[1] == v2):
            del MatchedMST[i]

    return MatchedMST

if __name__=="__main__":
    print(coordinates)
    data_sorted = tsp(coordinates)
# Out:
# [(49.276774, -123.12523), (49.841375, -119.487573), (49.500151, -117.283269), (49.23206, -123.032935), (51.08277, -114.154081)]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 194>()
#     194 if __name__=="__main__":
#     195     print(coordinates)
# --> 196     data_sorted = tsp(coordinates)
#
# Input In [2], in tsp(data)
#       1 def tsp(data):
#       2     # build a graph
# ----> 3     G = build_graph(data)
#       4 #   print("Graph: ", G)
#       5
#       6     # build a minimum spanning tree
#       7     MSTree = minimum_spanning_tree(G)
#
# Input In [2], in build_graph(data)
#      45 def build_graph(data):#O(n^2)
#      46     # from json
#      47     with open('distance.json') as  f:
# ---> 48         dist = json.load(f)
#      50     graph = {}
#      51     for point1 in range(len(data)):
#
# NameError: name 'json' is not defined

# %% [markdown]
# # Plot the polygon

# %%
# create latitude and longitude with order
order = data_sorted[1]
lat = []
long = []
loc = []

for i in range(len(order)):
    lat.append(data[order[i]][0])
    long.append(data[order[i]][1])
    loc.append(data[order[i]])
    
print(lat)
print(long)
print(loc)
# Out:
# [49.23206, 49.276774, 49.500151, 49.841375, 51.08277, 49.23206]
# [-123.032935, -123.12523, -117.283269, -119.487573, -114.154081, -123.032935]
# [(49.23206, -123.032935), (49.276774, -123.12523), (49.500151, -117.283269), (49.841375, -119.487573), (51.08277, -114.154081), (49.23206, -123.032935)]

# %%
#Google API

API_KEY=''

def urlparserwaypoint(coordinates):
    n = len(coordinates)
    txt1 = []
    
    # loop all except the first and last
    for coordinate in coordinates[1:-1]:
        txt1.append(','.join(list(map(str, coordinate))))
    txt = 'via:' + '|via:'.join(txt1)
    return urllib.parse.quote(txt)


origin = urllib.parse.quote(','.join(list(map(str, loc[0]))))
waypoints = urlparserwaypoint(loc)

print(waypoints)
url = ("https://maps.googleapis.com/maps/api/directions/json"
       + "?destination={}"
       + "&origin={}"
       + "&waypoints={}"
       + "&key={}").format(origin, origin, waypoints, API_KEY)
payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# via%3A49.276774%2C-123.12523%7Cvia%3A49.500151%2C-117.283269%7Cvia%3A49.841375%2C-119.487573%7Cvia%3A51.08277%2C-114.154081
# {
#    "geocoded_waypoints" : [
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJzd5M1pF2hlQRoOGbt7bQHwo",
#          "types" : [ "atm", "establishment", "finance", "point_of_interest" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJYZoTsqNzhlQR6eIIwOVx0j4",
#          "types" : [ "establishment", "point_of_interest", "store" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJCcOgrrK2fFMRYHivFeBoQi8",
#          "types" : [ "premise" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJyRfSUA6LfVMRX7KIBlhxqWY",
#          "types" : [ "establishment", "point_of_interest" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJTQJkKxxvcVMRgdQrG6Hl5ag",
#          "types" : [ "premise" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJzd5M1pF2hlQRoOGbt7bQHwo",
#          "types" : [ "atm", "establishment", "finance", "point_of_interest" ]
#       }
#    ],
#    "routes" : [
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 51.50168009999999,
#                "lng" : -114.1539572
#             },
#             "southwest" : {
#                "lat" : 49.0048016,
#                "lng" : -123.1095676
#             }
#          },
#          "copyrights" : "Map data ©2022 Google",
#          "legs" : [
#             {
#                "distance" : {
#                   "text" : "2,581 km",
#                   "value" : 2581173
#                },
#                "duration" : {
#                   "text" : "1 day 5 hours",
#                   "value" : 105821
#                },
#                "end_address" : "3410 Kingsway, Vancouver, BC V5R 5L4, Canada",
#                "end_location" : {
#                   "lat" : 49.2320563,
#                   "lng" : -123.0327931
#                },
#                "start_address" : "3410 Kingsway, Vancouver, BC V5R 5L4, Canada",
#                "start_location" : {
#                   "lat" : 49.2320563,
#                   "lng" : -123.0327931
#                },
#                "steps" : [
#                   {
#                      "distance" : {
#                         "text" : "38 m",
#                         "value" : 38
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 27
#                      },
#                      "end_location" : {
#                         "lat" : 49.23235760000001,
#                         "lng" : -123.0325454
#                      },
#                      "html_instructions" : "Head \u003cb\u003enortheast\u003c/b\u003e toward \u003cb\u003eKingsway\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-1A\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-99A N\u003c/b\u003e",
#                      "polyline" : {
#                         "points" : "ksnkH|y|mV_@UIGQQ"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2320563,
#                         "lng" : -123.0327931
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "5.6 km",
#                         "value" : 5631
#                      },
#                      "duration" : {
#                         "text" : "12 mins",
#                         "value" : 710
#                      },
#                      "end_location" : {
#                         "lat" : 49.2598294,
#                         "lng" : -123.096413
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eKingsway\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-1A\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-99A N\u003c/b\u003e",
#                      "maneuver" : "turn-left",
#                      "polyline" : {
#                         "points" : "gunkHlx|mVQQy@lBMZEb@{@pBOJ}AlDs@dBs@bB}@zBc@fAkA`EeApDK`@IZQx@If@ADIr@C\\E^AXEx@Er@KrBE~@KjBC\\A^GlBErACt@GlBGnACTAXCRCVEXKn@Kj@GXIZK^Md@St@y@tCQj@o@tBk@vAOb@Sn@MZa@hAc@rAQh@c@lA}AhEUr@ITKVEPCBWr@IXm@~Aa@`Au@rBGPo@hBa@hAEJMZEPCHGh@Od@ELYv@Wr@c@hACFMJ?@GJOb@g@tACDe@nAITMXi@`B[z@Mb@K\\Sn@GNEROl@u@vBCHSj@Qd@g@vAe@rA{@xBeBrEYb@e@hAUh@GNYr@Sd@]x@G\\Un@e@pAK^m@~Ak@bBSj@@No@hB}AhEcBzE}BjG_@jAONEFEFQb@GPA@ABC@GPSj@qArDi@dBu@|BqAdEWv@Qj@Id@Y`@eA|BWh@eAzBg@lA_@bAi@xAEJoAdD?Z_AfCMZ{@bC[z@g@rA_@fACDYt@kAdDq@jB_CnGeBrEy@zBWl@oBtFE@A@A@A@A@?@A@ITKXUh@S^[t@IZuAbEWpAKr@Gd@CZCZE^ALAJAHAFAFADEPALEN?@CHCJEPUl@yAbDCHs@vAUb@INOVIPQ\\Yj@KRs@~AWb@MRWb@YX"
#                      },
#                      "start_location" : {
#                         "lat" : 49.23235760000001,
#                         "lng" : -123.0325454
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "1.4 km",
#                         "value" : 1353
#                      },
#                      "duration" : {
#                         "text" : "3 mins",
#                         "value" : 191
#                      },
#                      "end_location" : {
#                         "lat" : 49.2604609,
#                         "lng" : -123.1149368
#                      },
#                      "html_instructions" : "Slight \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eE 12th Ave\u003c/b\u003e",
#                      "maneuver" : "turn-slight-left",
#                      "polyline" : {
#                         "points" : "}`tkHpginVAr@_@|BIz@OdACXADGTER@x@A~D?l@?`C@d@AfA?b@?b@EtHAb@D^ArBAt@CtDCzEAfD?ZAbDApAAdC?z@?Z?J?D@HAnC?vBA^?VAfAAJ?n@G|@ElDA|C?b@?ZAbD"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2598294,
#                         "lng" : -123.096413
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.5 km",
#                         "value" : 541
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 121
#                      },
#                      "end_location" : {
#                         "lat" : 49.2653188,
#                         "lng" : -123.1147211
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eCambie St\u003c/b\u003e",
#                      "maneuver" : "turn-right",
#                      "polyline" : {
#                         "points" : "{dtkHj{lnVuAAiCEQ?M?kAI[Ac@Au@AIAc@Am@CUAo@?eB?aBAsAEkAA"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2604609,
#                         "lng" : -123.1149368
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.9 km",
#                         "value" : 900
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 62
#                      },
#                      "end_location" : {
#                         "lat" : 49.27341070000001,
#                         "lng" : -123.1146941
#                      },
#                      "html_instructions" : "Keep \u003cb\u003eleft\u003c/b\u003e to stay on \u003cb\u003eCambie St\u003c/b\u003e",
#                      "maneuver" : "keep-left",
#                      "polyline" : {
#                         "points" : "gcukH~ylnVq@DU@c@?S?m@@e@@G?I?K?cA?}BF]?]@w@@A?M@E?QA_BDG?_ABE?eBAsDKeAA_@AA?GAC?QAQ?CA{A?qACWAWAi@?A?g@A]?_@AUAWA"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2653188,
#                         "lng" : -123.1147211
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.8 km",
#                         "value" : 766
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 111
#                      },
#                      "end_location" : {
#                         "lat" : 49.27903509999999,
#                         "lng" : -123.1194952
#                      },
#                      "html_instructions" : "Continue onto \u003cb\u003eCambie St Bridge\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eSmithe St\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eContinue to follow Smithe St\u003c/div\u003e",
#                      "polyline" : {
#                         "points" : "yuvkHxylnV[AC?g@AQAq@AE?OASAgACC?u@Ae@CO?G@SBKBI@G@C@IDMDKDIHUJSJKHSRKLQNKPKPEJCDIRMTg@|@gAnB]p@]p@w@rAw@rAOV_AbB{@xAaAfB"
#                      },
#                      "start_location" : {
#                         "lat" : 49.27341070000001,
#                         "lng" : -123.1146941
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.5 km",
#                         "value" : 491
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 100
#                      },
#                      "end_location" : {
#                         "lat" : 49.2758822,
#                         "lng" : -123.1242288
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eRichards St\u003c/b\u003e",
#                      "maneuver" : "turn-left",
#                      "polyline" : {
#                         "points" : "_ywkHzwmnV`@p@xBvDr@jAzAhClBbDJN~@`BDFl@dAVb@`@r@b@t@"
#                      },
#                      "start_location" : {
#                         "lat" : 49.27903509999999,
#                         "lng" : -123.1194952
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.2 km",
#                         "value" : 200
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 60
#                      },
#                      "end_location" : {
#                         "lat" : 49.27714599999999,
#                         "lng" : -123.1261827
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eDavie St\u003c/b\u003e",
#                      "maneuver" : "turn-right",
#                      "polyline" : {
#                         "points" : "gewkHlunnVOVQ\\S^IJ[h@c@v@y@xAADaA`B"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2758822,
#                         "lng" : -123.1242288
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.3 km",
#                         "value" : 330
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 89
#                      },
#                      "end_location" : {
#                         "lat" : 49.2792748,
#                         "lng" : -123.12302
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eGranville St\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eParts of this road may be closed at certain times or days\u003c/div\u003e",
#                      "maneuver" : "turn-right",
#                      "polyline" : {
#                         "points" : "emwkHraonVqE}HqCuEg@y@[i@"
#                      },
#                      "start_location" : {
#                         "lat" : 49.27714599999999,
#                         "lng" : -123.1261827
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.1 km",
#                         "value" : 102
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 40
#                      },
#                      "end_location" : {
#                         "lat" : 49.2786307,
#                         "lng" : -123.1220215
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e at the 2nd cross street onto \u003cb\u003eNelson St\u003c/b\u003e",
#                      "maneuver" : "turn-right",
#                      "polyline" : {
#                         "points" : "mzwkHzmnnV`AgBLSTc@Xg@"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2792748,
#                         "lng" : -123.12302
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.5 km",
#                         "value" : 506
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 112
#                      },
#                      "end_location" : {
#                         "lat" : 49.2818654,
#                         "lng" : -123.1171234
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eSeymour St\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-99 N\u003c/b\u003e",
#                      "maneuver" : "turn-left",
#                      "polyline" : {
#                         "points" : "mvwkHrgnnVeCiEEIcAeBKUGIw@wA_@i@gB_DmCwEuA_C"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2786307,
#                         "lng" : -123.1220215
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "1.2 km",
#                         "value" : 1189
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 123
#                      },
#                      "end_location" : {
#                         "lat" : 49.2771497,
#                         "lng" : -123.1034335
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eW Georgia St\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-1A\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-99A S\u003c/b\u003e (signs for \u003cb\u003eBC-99 E\u003c/b\u003e)",
#                      "maneuver" : "turn-right",
#                      "polyline" : {
#                         "points" : "ujxkH~hmnV`A}A|@_Bn@gANW~@_Bt@sA@AdAmBd@{@\\m@x@wAf@}@LY`AkBLSLYj@iALSRa@\\u@HQVm@JWL[BGPm@Ni@@GH]Lq@Fe@Fe@BYDe@Do@@e@@[?Q?O@U@w@DmI?w@@mB?e@@Q@yD@aA@cA"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2818654,
#                         "lng" : -123.1171234
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.3 km",
#                         "value" : 256
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 29
#                      },
#                      "end_location" : {
#                         "lat" : 49.2767839,
#                         "lng" : -123.0999533
#                      },
#                      "html_instructions" : "Take the ramp to \u003cb\u003eHistoric Chinatown\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eMay be closed at certain times or days\u003c/div\u003e",
#                      "maneuver" : "ramp-right",
#                      "polyline" : {
#                         "points" : "emwkHlsjnVFk@Do@FeA@SHwAB_@H}AHoADaABqA@OBw@"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2771497,
#                         "lng" : -123.1034335
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.4 km",
#                         "value" : 432
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 74
#                      },
#                      "end_location" : {
#                         "lat" : 49.27290139999999,
#                         "lng" : -123.1001058
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eMain St\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-1A\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-99A S\u003c/b\u003e",
#                      "maneuver" : "turn-right",
#                      "polyline" : {
#                         "points" : "{jwkHt}inVF?D@bCBhCDlA@T@jCFtA@dDD"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2767839,
#                         "lng" : -123.0999533
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "1.2 km",
#                         "value" : 1190
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 122
#                      },
#                      "end_location" : {
#                         "lat" : 49.270125,
#                         "lng" : -123.0844723
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eTerminal Ave\u003c/b\u003e",
#                      "maneuver" : "turn-left",
#                      "polyline" : {
#                         "points" : "srvkHt~inV^BBe@TqBXwCPkBj@mG^iEFk@^yDHs@\\uDJo@B_@dAmLh@cFF_@De@Fs@LsAFw@D_@BSNaBFk@p@wH@Kf@iG"
#                      },
#                      "start_location" : {
#                         "lat" : 49.27290139999999,
#                         "lng" : -123.1001058
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "4.0 km",
#                         "value" : 4032
#                      },
#                      "duration" : {
#                         "text" : "7 mins",
#                         "value" : 423
#                      },
#                      "end_location" : {
#                         "lat" : 49.2693846,
#                         "lng" : -123.0289954
#                      },
#                      "html_instructions" : "Continue onto \u003cb\u003eE 1st Ave\u003c/b\u003e",
#                      "polyline" : {
#                         "points" : "gavkH||fnVX_Df@mF?g@@KB[Dm@@Y@W?a@@e@?eB@uB?eB?wB@i@?A?k@@}B?s@?e@?]?_@?W?oA@{E?c@BaI?u@@qH?c@Fq@?yD@mB?sA@eC@iGEo@?kA?}B@w@?mA@q@?mB@mB?w@?A?u@@kD?{E@eD?Q@cE@yD@c@?_CDg@@u@B}@@_B@Q?m@?[@m@?mA?O?g@?O?e@?O?e@?O?w@?qF?sG@mO?sN?sD?aBAaB?{C?a@?gB?a@@cD@cF?yL?u@?G?wB?A?s@@iB?E?u@?u@?A?mB?wA?w@?A?u@?u@AoB@{@?o@?u@@c@?m@?IAyA?cA?mBAkE@oB@}G"
#                      },
#                      "start_location" : {
#                         "lat" : 49.270125,
#                         "lng" : -123.0844723
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eBoundary Rd S\u003c/b\u003e",
#                      "maneuver" : "turn-left",
#                      "polyline" : {
#                         "points" : "cwskHx_{mVB|@VAT@b@?b@@b@?^?N?`D?hBBZ?~B@b@?V?J?H?`B?rC?b@?dB?b@?D?\\?dBAlA?`@@n@@d@A`@?B?P?tA?zC@pB@jBArA?jDBvAAtAAB?jBCr@Ab@A\\?nAALAb@AvAEL?tB@LANEL?L?J?bABVDF?dA?jB?jA?h@AnB@PANA@ALAPCl@ELA@?LAN?PAJAD?PAF?J?^AfAAt@?H?nA?f@?lA?L?|@?`@CnB@nABv@@f@?j@Cf@@LA`A@H?^?hB?R?fAAtAAfA@h@?"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2582562,
#                         "lng" : -123.0234915
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.7 km",
#                         "value" : 656
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 92
#                      },
#                      "end_location" : {
#                         "lat" : 49.2324534,
#                         "lng" : -123.0324616
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eKingsway\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-1A\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eBC-99A N\u003c/b\u003e",
#                      "maneuver" : "turn-right",
#                      "polyline" : {
#                         "points" : "iunkHp`{mVH|D@p@BrAFbCHd@BlADvA@h@DnD@VDlB?l@Ev@@PF~C@n@@X?r@AL?NANALALALIx@E`@EXAHCFG`@Kb@Yx@"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2323749,
#                         "lng" : -123.0236084
#                      },
#                      "travel_mode" : "DRIVING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "51 m",
#                         "value" : 51
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 32
#                      },
#                      "end_location" : {
#                         "lat" : 49.2320563,
#                         "lng" : -123.0327931
#                      },
#                      "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e at \u003cb\u003eStamford St\u003c/b\u003e",
#                      "maneuver" : "turn-left",
#                      "polyline" : {
#                         "points" : "yunkHzw|mVPPPPHF^T"
#                      },
#                      "start_location" : {
#                         "lat" : 49.2324534,
#                         "lng" : -123.0324616
#                      },
#                      "travel_mode" : "DRIVING"
#                   }
#                ],
#                "traffic_speed_entry" : [],
#                "via_waypoint" : [
#                   {
#                      "location" : {
#                         "lat" : 49.2766504,
#                         "lng" : -123.1254123
#                      },
#                      "step_index" : 7,
#                      "step_interpolation" : 0.6067271366352102
#                   },
#                   {
#                      "location" : {
#                         "lat" : 49.500152,
#                         "lng" : -117.2832282
#                      },
#                      "step_index" : 30,
#                      "step_interpolation" : 0.2622137089637383
#                   },
#                   {
#                      "location" : {
#                         "lat" : 49.84128949999999,
#                         "lng" : -119.4878616
#                      },
#                      "step_index" : 45,
#                      "step_interpolation" : 1
#                   },
#                   {
#                      "location" : {
#                         "lat" : 51.0826593,
#                         "lng" : -114.1540121
#                      },
#                      "step_index" : 64,
#                      "step_interpolation" : 0.5310224660445948
#                   }
#                ]
#             }
#          ],
#          "overview_polyline" : {
#             "points" : "ksnkH|y|mVuoDz~Mcz@ihDjwCupb@vkh@awwBkoQ}we@egDsya@w{Kaei@glOinHmhLmjf@pzEyaZb`MujPlxGywa@|eUq_d@z|G_tKckDgoQg_NocU}iGodBsvNnnCmgNka@szOmbIzzB}_j@n_Jwg\\t|IanTtgQ}{LzhCqq[voIk|OfjJkrC|zIktAr}@{_GmdHqaSddIc{^jWywg@wyDg`[nb@}i]`rFu{Vy~NaoOigHcpKazBamLn{V}\\v}Ay`Gmc@ocPruAu{[yqHasHuvH~kAkmHqmWmiL{lAokE{gIbd@ykNauGivd@rc@mkSikH}gJglVu_NgxEolk@d\\nrY`oKt{Q`v\\ju\\yhDfd^ptHn}`@fdFxbQpwEiDx~FlqFduAn~KvyGuJvqJx~CjXd~RexAvwV~kCleNunOdQ{wIig@fp@hdJplDhzOxmKvcBl{DxmUa_Fhnb@inSg`AiyP`yCsxMb_E_mOprJwgKu^afGf{B_~UunHmcP|aHixGtnAgiH{_Fi}I~|Nxc@p{UevApiVx_EtpOs|H_gMowMwuDsoNn~CaaWkzHaiPi~OgjX}lIcgN{rNobYbjAknUeoV_h^_fUmsUwij@hwDysd@h`FwiG}lCuvIgxFgkYaVa~Yq}Gkf\\qaXmcf@ouLqhXe}BcnTgxGynCukCkmKe_IwWw`Wdx@~|Cwal@_s@anGh|GcyS`nW}aTnn@cjRxlPsvw@y~PwWu}Sa|WcjDokUbGylTvuImgRniZa|n@vkM_u[mo@arX}|A{fTviNy_VhkM{i\\sgCykZetQmt~@bnMank@wD_nv@he@y{Q_d@vsNq\\~||@{}Kv|l@lwPro`AntDtsXi~Wvff@e_FnhPrbGhkXk~R`nq@ciYrdj@q`Hh}QlYx~RjbE`rUhhTb`UxwNj_CcoJj`b@qlHdsf@otV`_UaoGllT|m@nmHsW`aj@hhW{oE~hMbsMxpDf}E~{C|vTb{Lz`Xh}KzgVhnJxuNhiHpr[b]jo[bwFrfXf`CjcJybGtfGej@`oh@|fRhce@drOxc]t|Gly\\lhHpvK{tCj~CynU|{@giH~rh@p~Rbt`@zgPjpQlqHv`WmzC`_v@vuBha_@km@baQnyMhGboMfuBlaIzbSz}a@|cGfeXj~O~jKzyD`gLh{LpoH|_QbpKa{@ntXf~OvvNxcCxmNtzEnjBdmSnbKj{HzoO|_KjjMlzNboApaZzlMntb@jpRjkMxaHv_r@j}Qzaf@m{@xqa@wiVjr`AobKj{l@zf@hfO"
#          },
#          "summary" : "Trans-Canada Hwy/BC-1 W",
#          "warnings" : [],
#          "waypoint_order" : []
#       }
#    ],
#    "status" : "OK"
# }

# %%
with open('direction.json', 'w') as f:
    json.dump(response.json(), f)

# %%
gmap = gmplot.GoogleMapPlotter(49.260942911888534, -123.11405788826303, 13, apikey="")

f = open('direction.json')
results = json.load(f)

pos = results["routes"][0]["legs"][0]["steps"]
startlat=results["routes"][0]["legs"][0]["steps"][0]["start_location"]["lat"]
startlong=results["routes"][0]["legs"][0]["steps"][0]["start_location"]["lng"]

leglat = [startlat]
leglong = [startlong]

#put latitude and longitude
for leg in pos:
    leglat.append(leg["end_location"]["lat"])
    leglong.append(leg["end_location"]["lng"])


# Plot the route taken (straight line):
# gmap.plot(lat, long, color='red', edge_width=5)
gmap.plot(leglat, leglong, color='cyan', edge_width=5)

attractions = zip(*loc)
# Mark the distribution center:
gmap.scatter(
    *attractions,
    color=['red', 'orange', 'yellow', 'green', 'blue', 'purple'],
    s=60,
    ew=2,
    marker=True,
    title=[None, None, None, 'Third', None, None],
    label=['A', 'B', 'C', 'D', 'E', 'F']
)

# Draw the map:
gmap.draw('map.html')
